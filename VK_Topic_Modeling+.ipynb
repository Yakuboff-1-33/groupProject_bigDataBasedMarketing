# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style
import seaborn as sns
# %matplotlib inline  
style.use('fivethirtyeight')
sns.set(style='whitegrid',color_codes=True)

import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize,sent_tokenize

#preprocessing
from nltk.corpus import stopwords  #stopwords
from nltk import word_tokenize,sent_tokenize # tokenizing
from nltk.stem import PorterStemmer,LancasterStemmer  # using the Porter Stemmer and Lancaster Stemmer and others
from nltk.stem.snowball import SnowballStemmer
from nltk.stem import WordNetLemmatizer  # lammatizer from WordNet

# for named entity recognition (NER)
from nltk import ne_chunk

# vectorizers for creating the document-term-matrix (DTM)
from sklearn.feature_extraction.text import TfidfVectorizer,CountVectorizer

# %%
VK = pd.read_csv('/content/VK_music_reviews_newest_2000.csv')
VK.head()
# Out:
#         time_submitted                                             review  \
# 0  2022-11-02 18:13:20  Не могу понять где моя музыка который ВКонтакт...
# 1  2022-11-02 18:11:22                                                Топ
# 2  2022-11-02 18:10:13  Сделайте так, чтобы можно было посмотреть музы...
# 3  2022-11-02 17:59:47                 Не работает без интернета. Вранье.
# 4  2022-11-02 17:48:18  Качество звука очень нравится! Да и пользовать...
#
#    rating  author_account_name  \
# 0       3         Петр Хадаров
# 1       5           Миста 4444
# 2       4        Rishat Vaziev
# 3       1  Liliya Karshgalieva
# 4       5        Юлия Туманова
#
#                                                reply
# 0  Напишите, пожалуйста, о вашей проблеме в подде...
# 1  Спасибо ваша поддержка мотивирует нас и вдохно...
# 2  Спасибо, возьмём на заметку. ВКонтакте быстро ...
# 3  Понимаем, это неприятно. Но к сожалению, через...
# 4  Спасибо за ваши тёплые слова, мы будем и дальш...

# %%
VK.drop(['time_submitted'],axis=1,inplace=True)
VK.drop(['author_account_name'],axis=1,inplace=True)

# %%
VK.head(10)
# Out:
#                                               review  rating  \
# 0  Не могу понять где моя музыка который ВКонтакт...       3
# 1                                                Топ       5
# 2  Сделайте так, чтобы можно было посмотреть музы...       4
# 3                 Не работает без интернета. Вранье.       1
# 4  Качество звука очень нравится! Да и пользовать...       5
# 5  Почему я не могу слушать музыку я купил у вас ...       1
# 6                    помню как оно называлось BOOM 😌       5
# 7       Лучшее приложение для прослушивания музыки🙌🏻       5
# 8  Оцениваю на четыре звёзды патомушто я не скачи...       4
# 9                           Лагает до невыносимости.       1
#
#                                                reply
# 0  Напишите, пожалуйста, о вашей проблеме в подде...
# 1  Спасибо ваша поддержка мотивирует нас и вдохно...
# 2  Спасибо, возьмём на заметку. ВКонтакте быстро ...
# 3  Понимаем, это неприятно. Но к сожалению, через...
# ...

# %%
def clean_text(review):
  le=WordNetLemmatizer()
  word_tokens=word_tokenize(review)
  tokens=[le.lemmatize(w) for w in word_tokens if w not in stop_words and len(w)>3]
  cleaned_text=" ".join(tokens)
  return cleaned_text

# %%
import nltk
nltk.download('stopwords')
nltk.download('wordnet') 
nltk.download('omw-1.4')
stop_words=set(nltk.corpus.stopwords.words('english'))

nltk.download('punkt')
VK['review_cleaned_text']=VK['review'].apply(clean_text)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
VK.head()
# Out:
#                                               review  rating  \
# 0  Не могу понять где моя музыка который ВКонтакт...       3
# 1                                                Топ       5
# 2  Сделайте так, чтобы можно было посмотреть музы...       4
# 3                 Не работает без интернета. Вранье.       1
# 4  Качество звука очень нравится! Да и пользовать...       5
#
#                                                reply  \
# 0  Напишите, пожалуйста, о вашей проблеме в подде...
# 1  Спасибо ваша поддержка мотивирует нас и вдохно...
# 2  Спасибо, возьмём на заметку. ВКонтакте быстро ...
# 3  Понимаем, это неприятно. Но к сожалению, через...
# 4  Спасибо за ваши тёплые слова, мы будем и дальш...
#
#                                  review_cleaned_text
# 0  могу понять музыка который ВКонтакте могу доба...
# 1
# 2  Сделайте чтобы можно было посмотреть музыки св...
# 3                          работает интернета Вранье
# 4  Качество звука очень нравится пользоваться удо...

# %%
VK.drop(['review'],axis=1,inplace=True)
VK.head()
# Out:
#    rating                                              reply  \
# 0       3  Напишите, пожалуйста, о вашей проблеме в подде...
# 1       5  Спасибо ваша поддержка мотивирует нас и вдохно...
# 2       4  Спасибо, возьмём на заметку. ВКонтакте быстро ...
# 3       1  Понимаем, это неприятно. Но к сожалению, через...
# 4       5  Спасибо за ваши тёплые слова, мы будем и дальш...
#
#                                  review_cleaned_text
# 0  могу понять музыка который ВКонтакте могу доба...
# 1
# 2  Сделайте чтобы можно было посмотреть музыки св...
# 3                          работает интернета Вранье
# 4  Качество звука очень нравится пользоваться удо...

# %%
VK['review_cleaned_text'][0]
# Out:
# 'могу понять музыка который ВКонтакте могу добавит артистов сохраняется'

# %%
vect =TfidfVectorizer(stop_words=stop_words,max_features=1000)

# %%
vect_text=vect.fit_transform(VK['review_cleaned_text'])

# %%
print(vect_text.shape)
print(vect_text)
# Out:
# (2000, 1000)
#   (0, 841)	0.41624986086515087
#   (0, 21)	0.3749850030873928
#   (0, 88)	0.3280460819581531
#   (0, 325)	0.35936577478659937
#   (0, 398)	0.1960488858031122
#   (0, 648)	0.40539578351776223
#   (0, 384)	0.49657164829921635
#   (2, 136)	0.46408337091328367
#   (2, 787)	0.43645055405648847
#   (2, 402)	0.2576868283688189
#   (2, 661)	0.42277466317131734
#   (2, 52)	0.2826255825166074
#   (2, 391)	0.26773586645676567
#   (2, 980)	0.29015911205888884
#   (2, 790)	0.33651834568138544
#   (3, 273)	0.7942032710329945
#   (3, 736)	0.6076521737643107
#   (4, 748)	0.3138597902439056
#   (4, 843)	0.23915019701609008
#   (4, 533)	0.24564163206377662
#   (4, 336)	0.271869246299605
#   (4, 123)	0.2910955830837028
#   (4, 127)	0.33037758156805125
#   (4, 697)	0.27875062145263
#   (4, 926)	0.2486856938086299
#   :	:
#   (1995, 729)	0.20504256265098872
#   (1995, 696)	0.12275002520298779
#   (1995, 736)	0.20907836676810243
#   (1996, 419)	0.31520633688899374
# ...

# %%
idf=vect.idf_

# %%
dd=dict(zip(vect.get_feature_names(), idf))
l=sorted(dd, key=(dd).get)
# print(l)
print(l[0],l[-1])
print(dd['музыка'])
# Out:
# приложение звучания
# 3.2931346371825287

# %%
from sklearn.decomposition import TruncatedSVD
lsa_model = TruncatedSVD(n_components=10, algorithm='randomized', n_iter=10, random_state=42)

lsa_top=lsa_model.fit_transform(vect_text)

# %%
print(lsa_top)
print(lsa_top.shape)
# Out:
# [[ 0.04471818  0.00119001 -0.10777538 ...  0.01279112  0.01850776
#    0.10679034]
#  [ 0.          0.          0.         ...  0.          0.
#    0.        ]
#  [ 0.07185993  0.00386764 -0.10301806 ...  0.01459333  0.01100618
#   -0.05897532]
#  ...
#  [ 0.10592301  0.01314709 -0.15950785 ...  0.12842619 -0.08847832
#   -0.03575601]
#  [ 0.03424312  0.02682667 -0.0316098  ...  0.36847116  0.89797342
#   -0.04079648]
#  [ 0.024302    0.00177401 -0.06184403 ...  0.06708744 -0.02742216
#   -0.02261927]]
# (2000, 10)

# %%
l=lsa_top[0]
print("Document 0 :")
for i,topic in enumerate(l):
  print("Topic ",i," : ",topic*100)
# Out:
# Document 0 :
# Topic  0  :  4.4718178091821645
# Topic  1  :  0.1190006003687366
# Topic  2  :  -10.777538359150185
# Topic  3  :  3.5832597358822578
# Topic  4  :  -8.85432172348234
# Topic  5  :  -7.022738422025716
# Topic  6  :  3.4728737639680785
# Topic  7  :  1.2791119527814687
# Topic  8  :  1.8507756060253917
# Topic  9  :  10.679034130795182

# %%
print(lsa_model.components_.shape)
print(lsa_model.components_)
# Out:
# (10, 1000)
# [[ 5.14454369e-03  1.74326348e-03  2.07571602e-03 ...  1.43292168e-02
#    2.67657091e-03  2.16689567e-03]
#  [-1.76086770e-04 -2.06173011e-04  4.26611670e-05 ... -8.51205591e-04
#    1.79241692e-05  6.24882701e-05]
#  [-7.07864980e-03 -1.10928036e-03 -4.73569265e-03 ... -1.76836590e-02
#   -4.95630281e-03 -4.84766175e-03]
#  ...
#  [ 5.21862250e-04 -1.46031850e-03 -5.93731389e-04 ... -3.04781622e-03
#   -7.50942232e-04  1.01862456e-03]
#  [-1.65790175e-03  6.31066982e-04  5.60310523e-04 ...  2.05534822e-03
#    6.16570350e-04 -2.35303232e-04]
#  [-2.51538930e-03 -1.25211335e-03  1.24787777e-03 ... -1.53960679e-02
#   -4.74763723e-03 -2.71002726e-03]]

# %%
# most important words for each topic
vocab = vect.get_feature_names()

for i, comp in enumerate(lsa_model.components_):
    vocab_comp = zip(vocab, comp)
    sorted_words = sorted(vocab_comp, key= lambda x:x[1], reverse=True)[:10]
    print("Topic "+str(i)+": ")
    for t in sorted_words:
        print(t[0],end=" ")
    print("\n")
# Out:
# Topic 0:
# приложение отличное очень хорошее музыку удобное супер крутое музыка музыки
#
# Topic 1:
# супер спасибо просто класс отлично пока нравится очень приложения было
#
# Topic 2:
# отличное приложение супер преложение звезд нашёл лучшее цена никаких месяца
#
# Topic 3:
# норм отлично отличное музыка подписку музыку работает пока слушать музыки
#
# Topic 4:
# норм круто очень нравится класс приложение крутое удобное хорошее классно
#
# Topic 5:
# отлично нравится класс очень приложение работает удобное хорошее пока крутое
#
# Topic 6:
# круто отличное отлично музыка музыку слушать подписку приложения могу было
#
# Topic 7:
# отличное нравится класс очень удобно хорошо музыка пока норм музыку
#
# Topic 8:
# класс круто приложение подписку просто оформить могу большое спасибо почти
#
# Topic 9:
# подписку оформить могу нравится отменить получается купить оплатить продлить очень
